# %%
from pylab import * 
import netCDF4

name = "CDP_hor_19930801_20170731_Surface_temperature_ok.nc"

hor=netCDF4.Dataset(name)
time = hor.variables['time']
date=netCDF4.num2date(time[:], time.units)

# %%
# %matplotlib notebook
def read(var):
    variable=hor.variables[var]
    plot(date,variable,'+')
    show()

# %%
read('Surface_temperature')
# Out:
# <img src="data:image/png;base64,...">

# %%
read('Soil_temperature_20cm_1')
